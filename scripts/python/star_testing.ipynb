# %%
multi = [50,100,100,200,200,400,800,1600,1500,3000]
for i,k in  list(zip(multi,multi[1:]))[::2]:
     print(str(i), '+', str(k), '=', str(i+k))
# Out:
# 50 + 100 = 150
# 100 + 200 = 300
# 200 + 400 = 600
# 800 + 1600 = 2400
# 1500 + 3000 = 4500

# %%
multi[::2]
# Out:
# [50, 100, 200, 800, 1500]

# %%
multi[0::2]
# Out:
# [50, 100, 200, 800, 1500]
