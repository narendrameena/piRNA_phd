# %%
# Load the required libraries
library(ggpubr)


# Read the data from the CSV file
data <- read.table("/mnt/home3/miska/nm667/scratch/inProgress/mice_PiRNA/analysis/RNA_deSeq/RNA_Mapping.csv", header = TRUE, sep = ";")
# Round the values in the Measure_Values column to two decimal places
data$Measure_Values <- round(data$Measure_Values, 2)
# Remove rows with NA values using na.omit
data <- na.omit(data)
# Define the desired order of Strains
desired_strains_order <- c('C57BL_6NJ', 'BALB_cJ', 'A_J', 'FVB_NJ', 'C3H_HeJ', 'LP_J', '129S1_SvImJ', 'DBA_2J', 'AKR_J', 'CBA_J', 'NZO_HlLtJ', 'NOD_ShiLtJ', 'WSB_EiJ', 'CAST_EiJ', 'PWK_PhJ', 'SPRET_EiJ')

# Define the desired order of Measure_Names based on unique, unique loci, and multi loci
desired_measure_order <- c( "Unique", "Multiple Loci","Many Loci")  # Replace with your order

# Define the desired order for Timepoint
desired_timepoint_order <- c("E16.5", "P12.5", "P20.5")

# Create a custom factor with the desired order for Timepoint
data$Timepoint <- factor(data$Timepoint, levels = desired_timepoint_order)

# Create a custom factor with the desired order for Measure_Names
data$Measure_Names <- factor(data$Measure_Names, levels = desired_measure_order)

# Create a custom factor with the desired order for Strains
data$Strains <- factor(data$Strains, levels = desired_strains_order)

# Define custom colors for stacked bars and error bars
stacked_bar_colors <- c("#ff7f0e","#1f77b4",  "#2ca02c", "#d62728")  # Replace with your colors
error_bar_color <- "#000000"   # Replace with your color

# Your existing code for reading and preprocessing data here...
# Create the stacked bar plot with error bars using ggbarplot
plot <- ggbarplot(data,
          x = "Timepoint", y = "Measure_Values", 
          fill= "Measure_Names",
          add = "mean_se",
          width =0.8,
          add.params = list(color = "#000000"),
          nrow =1,
          size= 0.4,
          facet.by = "Strains",
          error.plot = "errorbar",
          title = "Bulk RNA Mapping Rate") + 
   # Apply ggpubr theme for consistency  # Major breaks every 10
  geom_hline(yintercept = seq(0, 95, by = 5), linetype = "dashed", color = "lightgrey", size = 0.0001) + # Add minor grid lines
  geom_hline(yintercept = seq(0, 90, by = 10), linetype = "dashed", color = "lightgrey", size = 0.0001) + 
  theme_pubr() + 
  labs(x = "Timepoint", y = "%") +  # Customize axis labels
  scale_fill_manual(values = stacked_bar_colors) +  # Set custom fill colors  
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 90, hjust = 1, size=6),
        strip.text.x = element_text(angle = 90, vjust = 0.5, hjust = 0.1),
        axis.ticks.y = element_line(color = "black"),
        panel.ontop = FALSE) +  # Ensure bars are drawn on top of grid lines
  scale_y_continuous(breaks = seq(0, 130, by = 10)) 
plot
# Save the plot as a PDF file
ggsave("RNA_MApping_stacked_bar_plot.pdf", plot = plot, device = "pdf", width = 8, height = 4)
# Out:
# plot without title

# %%
ggplot(data, aes(x = Timepoint, y = Measure_Values, fill = Measure_Names)) +
  geom_hline(yintercept = seq(0, 90, by = 10), linetype = "solid", color = "black", size = 0.5) +  # Add major grid lines up to 90
  geom_hline(yintercept = seq(0, 100, by = 5), linetype = "dashed", color = "grey", size = 0.5) +  # Add minor grid lines
  geom_bar(stat = "identity", position = position_stack(), width = 0.8) +
  theme_pubr() +  
  labs(x = "Timepoint", y = "%") +  
  scale_fill_manual(values = stacked_bar_colors) +  
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 90, hjust = 1, size=6),
        strip.text.x = element_text(angle = 90, vjust = 0.5, hjust = 0.1),
        axis.ticks.y = element_line(color = "black"),
        panel.ontop = FALSE) +  
  scale_y_continuous(breaks = seq(0, 100, by = 10)) +  # Major breaks every 10
  facet_wrap(~Strains,  nrow = 1)  # Adjusting facets
# Out:
# plot without title

# %%
# Load the required libraries
library(ggpubr)


# Read the data from the CSV file
data <- read.table("/mnt/home3/miska/nm667/scratch/inProgress/mice_PiRNA/analysis/RNA_deSeq/RNA_Mapping_2.csv", header = TRUE, sep = ";")
# Round the values in the Measure_Values column to two decimal places
data$Measure_Values <- round(data$Measure_Values, 2)
# Remove rows with NA values using na.omit
data <- na.omit(data)
# Define the desired order of Strains
desired_strains_order <- c('C57BL_6NJ', 'BALB_cJ', 'A_J', 'FVB_NJ', 'C3H_HeJ', 'LP_J', '129S1_SvImJ', 'DBA_2J', 'AKR_J', 'CBA_J', 'NZO_HlLtJ', 'NOD_ShiLtJ', 'WSB_EiJ', 'CAST_EiJ', 'PWK_PhJ', 'SPRET_EiJ')

# Define the desired order of Measure_Names based on unique, unique loci, and multi loci
desired_measure_order <- c( "Unique", "Multiple Loci","Many Loci")  # Replace with your order

# Define the desired order for Timepoint
desired_timepoint_order <- c("E16.5", "P12.5", "P20.5")

# Create a custom factor with the desired order for Timepoint
data$Timepoint <- factor(data$Timepoint, levels = desired_timepoint_order)

# Create a custom factor with the desired order for Measure_Names
data$Measure_Names <- factor(data$Measure_Names, levels = desired_measure_order)

# Create a custom factor with the desired order for Strains
data$Strains <- factor(data$Strains, levels = desired_strains_order)

# Define custom colors for stacked bars and error bars
stacked_bar_colors <- c("#ff7f0e","#1f77b4",  "#2ca02c", "#d62728")  # Replace with your colors
error_bar_color <- "#000000"   # Replace with your color

# Your existing code for reading and preprocessing data here...
# Create the stacked bar plot with error bars using ggbarplot
plot <- ggbarplot(data,
          x = "Timepoint", y = "Measure_Values", 
          fill= "Measure_Names",
          add = "mean_se",
          width =0.8,
          add.params = list(color = "#000000"),
          nrow =1,
          size= 0.4,
          facet.by = "Strains",
          error.plot = "errorbar",
          title = "Bulk RNA Mapping Rate") + 
  theme_pubr() +  # Apply ggpubr theme for consistency
  labs(x = "Timepoint", y = "%") +  # Customize axis labels
  scale_fill_manual(values = stacked_bar_colors) +  # Set custom fill colors  
  theme_minimal() +
   theme(axis.text.x = element_text(angle = 90, hjust = 1,size=6),
   strip.text.x = element_text(angle = 90, vjust = 0.5, hjust = 0.1))# Rotate x-axis labels for better readability
 
plot
# Save the plot as a PDF file
ggsave("RNA_MApping_stacked_bar_plot_wit_errroer.pdf", plot = plot, device = "pdf", width = 8, height = 4)
# Out:
# plot without title

# %%
# Create the stacked bar plot using ggplot2
plot <- ggplot(data, aes(x = Timepoint, y = Measure_Values, fill = Measure_Names)) +
  geom_bar(stat = "identity", position = "stack", width = 0.8) +
  geom_errorbar(data = data_summary, aes(x = Timepoint, ymin = mean_value - se, ymax = mean_value + se), width = 0.2, color = error_bar_color) +
  facet_wrap(~Strains, nrow = 1, scales = "free") +
  scale_fill_manual(values = stacked_bar_colors) +
  labs(title = "Bulk RNA Mapping Rate", x = "Timepoint", y = "%") +
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 90, hjust = 1, size = 6),
        strip.text.x = element_text(angle = 90, vjust = 0.5, hjust = 0.1))

print(plot)

# Save the plot as a PDF file
ggsave("RNA_MApping_stacked_bar_plot.pdf", plot = plot, device = "pdf", width = 8, height = 4)
# Out:
# Error in `geom_errorbar()`:
# ! Problem while computing aesthetics.
# ℹ Error occurred in the 2nd layer.
# Caused by error:
# ! object 'Measure_Values' not found
# Traceback:
#
# 1. print(plot)
# 2. print.ggplot(plot)
# 3. ggplot_build(x)
# 4. ggplot_build.ggplot(x)
# 5. by_layer(function(l, d) l$compute_aesthetics(d, plot), layers,
#  .     data, "computing aesthetics")
# 6. try_fetch(for (i in seq_along(data)) {
#  .     out[[i]] <- f(l = layers[[i]], d = data[[i]])
#  . }, error = function(cnd) {
#  .     cli::cli_abort(c("Problem while {step}.", i = "Error occurred in the {ordinal(i)} layer."),
#  .         call = layers[[i]]$constructor, parent = cnd)
#  . })
# 7. tryCatch(withCallingHandlers(expr, condition = function(cnd) {
#  .     {
#  .         .__handler_frame__. <- TRUE
#  .         .__setup_frame__. <- frame
#  .         if (inherits(cnd, "message")) {
#  .             except <- c("warning", "error")
#  .         }
#  .         else if (inherits(cnd, "warning")) {
# ...

# %%
# Use only "upper_errorbar"
ggbarplot(data, x = "Timepoint", y = "Measure_Values", fill= "Measure_Names", facet.by = "Strains",
 add = "mean_se", error.plot = "errorbar")
# Out:
# Warning message in stats::qt(ci/2 + 0.5, data_sum$length - 1):
# “NaNs produced”
# Warning message in stats::qt(ci/2 + 0.5, data_sum$length - 1):
# “NaNs produced”
# Warning message in stats::qt(ci/2 + 0.5, data_sum$length - 1):
# “NaNs produced”
# Warning message in stats::qt(ci/2 + 0.5, data_sum$length - 1):
# “NaNs produced”
# Warning message in stats::qt(ci/2 + 0.5, data_sum$length - 1):
# “NaNs produced”
# Warning message in stats::qt(ci/2 + 0.5, data_sum$length - 1):
# “NaNs produced”
# Warning message in stats::qt(ci/2 + 0.5, data_sum$length - 1):
# “NaNs produced”
# Warning message in stats::qt(ci/2 + 0.5, data_sum$length - 1):
# “NaNs produced”
# Warning message in stats::qt(ci/2 + 0.5, data_sum$length - 1):
# “NaNs produced”
# Warning message in stats::qt(ci/2 + 0.5, data_sum$length - 1):
# “NaNs produced”
# Warning message in stats::qt(ci/2 + 0.5, data_sum$length - 1):
# “NaNs produced”
# Warning message in stats::qt(ci/2 + 0.5, data_sum$length - 1):
# “NaNs produced”
# ...

# %%
library(ggplot2)
library(tidyr)
library(dplyr)
# Read the data from the CSV file
data <- read.table("/mnt/home3/miska/nm667/scratch/inProgress/mice_PiRNA/analysis/RNA_deSeq/RNA_Mapping.csv", header = TRUE, sep = ";")

# Calculate mean, standard error, and reorder Measure_Names
error_data <- data %>%
  group_by(Strains, Timepoint, Measure_Names) %>%
  summarize(Mean_Value = mean(Measure_Values),
            Error = sd(Measure_Values) / sqrt(n()))

# Define the desired order of Strains
desired_strains_order <- c('C57BL_6NJ', 'BALB_cJ', 'A_J', 'FVB_NJ', 'C3H_HeJ', 'LP_J', '129S1_SvImJ', 'DBA_2J', 'AKR_J', 'CBA_J', 'NZO_HlLtJ', 'NOD_ShiLtJ', 'WSB_EiJ', 'CAST_EiJ', 'PWK_PhJ', 'SPRET_EiJ')

# Create a custom factor with the desired order
error_data$Strains <- factor(error_data$Strains, levels = desired_strains_order)

# Define custom colors for stacked bars and error bars
stacked_bar_colors <- c("#1f77b4", "#ff7f0e", "#2ca02c", "#d62728")  # Replace with your colors
error_bar_color <- "#000000"   # Replace with your color

# Create the stacked bar plot with error bars
ggplot(error_data, aes(x = Timepoint, y = Mean_Value, fill = Measure_Names)) +
  geom_bar(stat = "identity", position = "stack") +
  geom_errorbar(aes(ymin = Mean_Value - Error, ymax = Mean_Value + Error),
                width = 0.4, position = position_dodge(0.5), color = error_bar_color) +
  scale_fill_manual(values = stacked_bar_colors) +
  scale_color_manual(values = error_bar_color) +  # Set the error bar color manually
  facet_grid(. ~ Strains) +
  labs(title = "Stacked Bar Plot with Error Bars",
       x = "Timepoint", y = "Mean Measure Values") +
  theme_minimal() +
  theme(legend.position = "bottom", 
        axis.text.x = element_text(angle = 90, hjust = 1),
        strip.text.x = element_text(angle = 90, vjust = 0.5, hjust = 1),
        panel.spacing = unit(0.1, "lines")) +
  coord_cartesian(ylim = c(0, max(error_data$Mean_Value + error_data$Error) * 1.1))
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# `summarise()` has grouped output by 'Strains', 'Timepoint'. You can override
# using the `.groups` argument.
# plot without title

# %%
# Read the data from the CSV file
data <- read.table("/mnt/home3/miska/nm667/scratch/inProgress/mice_PiRNA/analysis/RNA_deSeq/RNA_Mapping.csv", header = TRUE, sep = ";")

# Calculate mean, standard error, and reorder Measure_Names
error_data <- data %>%
  group_by(Strains, Timepoint, Measure_Names) %>%
  summarize(Mean_Value = mean(Measure_Values),
            Error = sd(Measure_Values) / sqrt(n()))

# Define the desired order of Strains
desired_strains_order <- c('C57BL_6NJ', 'BALB_cJ', 'A_J', 'FVB_NJ', 'C3H_HeJ', 'LP_J', '129S1_SvImJ', 'DBA_2J', 'AKR_J', 'CBA_J', 'NZO_HlLtJ', 'NOD_ShiLtJ', 'WSB_EiJ', 'CAST_EiJ', 'PWK_PhJ', 'SPRET_EiJ')

# Define the desired order of Measure_Names based on unique, unique loci, and multi loci
desired_measure_order <- c( "Unique", "Multiple Loci","Many Loci")  # Replace with your order

# Create a custom factor with the desired order for Measure_Names
error_data$Measure_Names <- factor(error_data$Measure_Names, levels = desired_measure_order)

# Create a custom factor with the desired order for Strains
error_data$Strains <- factor(error_data$Strains, levels = desired_strains_order)

# Define custom colors for stacked bars and error bars
stacked_bar_colors <- c("#ff7f0e","#1f77b4",  "#2ca02c", "#d62728")  # Replace with your colors
error_bar_color <- "#000000"   # Replace with your color

# Create the stacked bar plot with error bars
ggplot(error_data, aes(x = Timepoint, y = Mean_Value, fill = Measure_Names)) +
  geom_bar(stat = "identity", position = "stack") +
  geom_errorbar(aes(ymin =  Mean_Value - Error,
                    ymax =  Mean_Value + Error),width = 0.2, position = "identity", color = error_bar_color) +
  scale_fill_manual(values = stacked_bar_colors) + # Set the error bar color manually
  facet_grid(. ~ Strains) +
  labs(title = "STAR Bulk RNA Mapping",
       x = "Timepoint", y = "%") +
  theme_minimal() +
  theme(legend.position = "bottom", 
        axis.text.x = element_text(angle = 90, hjust = 1),
        strip.text.x = element_text(angle = 90, vjust = 0.5, hjust = 1),
        panel.spacing = unit(0.1, "lines"))
# Out:
# `summarise()` has grouped output by 'Strains', 'Timepoint'. You can override
# using the `.groups` argument.
# plot without title

# %%
# Read the data from the CSV file
data <- read.table("/mnt/home3/miska/nm667/scratch/inProgress/mice_PiRNA/analysis/RNA_deSeq/RNA_Mapping.csv", header = TRUE, sep = ";")

# Calculate mean, standard error, and reorder Measure_Names
error_data <- data %>%
  group_by(Strains, Timepoint, Measure_Names) %>%
  summarize(Mean_Value = mean(Measure_Values),
            Error = sd(Measure_Values) / sqrt(n()))

# Define the desired order of Strains
desired_strains_order <- c('C57BL_6NJ', 'BALB_cJ', 'A_J', 'FVB_NJ', 'C3H_HeJ', 'LP_J', '129S1_SvImJ', 'DBA_2J', 'AKR_J', 'CBA_J', 'NZO_HlLtJ', 'NOD_ShiLtJ', 'WSB_EiJ', 'CAST_EiJ', 'PWK_PhJ', 'SPRET_EiJ')

# Define the desired order of Measure_Names
desired_measure_order <- c("Unique", "Multiple Loci", "Many Loci")  # Update with your order

# Create a custom factor with the desired order for Measure_Names
error_data$Measure_Names <- factor(error_data$Measure_Names, levels = desired_measure_order)

# Create a custom factor with the desired order for Strains
error_data$Strains <- factor(error_data$Strains, levels = desired_strains_order)



# Define custom colors for stacked bars and error bars
stacked_bar_colors <- c("#ff7f0e", "#1f77b4", "#2ca02c", "#d62728")  # Replace with your colors
error_bar_color <- "#000000"   # Replace with your color

# Calculate the error bar x-coordinates based on stack positions
stack_positions <- unique(error_data$Timepoint)
error_data$Stack_X <- as.numeric(factor(error_data$Timepoint, levels = stack_positions))

# Create the stacked bar plot with adjusted error bar positions
ggplot(error_data, aes(x = Stack_X, y = Mean_Value, fill = Measure_Names)) +
  geom_bar(stat = "identity", position = "stack") +
  geom_errorbar(aes(x = Stack_X, ymin = Mean_Value - Error, ymax = Mean_Value + Error),
                width = 0.2, position = "identity", color = error_bar_color) +
  geom_text(aes(label = sprintf("%.2f", Mean_Value), group = Strains),
            position = position_stack(vjust = 0.8), size = 2, angle = 90, hjust = 0.5) +
  scale_fill_manual(values = stacked_bar_colors) +
  scale_color_manual(values = error_bar_color) +
  facet_grid(. ~ Strains) +
  labs(title = "Bulk RNA STAR Mapping",
       x = "Timepoint", y = "%") +
  theme_minimal() +
  theme(legend.position = "bottom",
        axis.text.x = element_text(angle = 90, hjust = 1),
        strip.text.x = element_text(angle = 90, vjust = 0.5, hjust = 1),
        panel.spacing = unit(0.1, "lines")) +
  coord_cartesian(ylim = c(0, max(error_data$Mean_Value + error_data$Error) * 1.1))
# Out:
# `summarise()` has grouped output by 'Strains', 'Timepoint'. You can override
# using the `.groups` argument.
# plot without title

# %%
library(ggpubr)


# Read the data from the CSV file
data <- read.table("/mnt/home3/miska/nm667/scratch/inProgress/mice_PiRNA/analysis/RNA_deSeq/RNA_Mapping.csv", header = TRUE, sep = "\t")

# %%
library(ggpubr)


# Read the data from the CSV file
data <- read.table("/mnt/home3/miska/nm667/scratch/inProgress/mice_PiRNA/analysis/RNA_deSeq/RNA_Mapping.csv", header = TRUE, sep = ";")


# Define the desired order of Strains
desired_strains_order <- c('C57BL_6NJ', 'BALB_cJ', 'A_J', 'FVB_NJ', 'C3H_HeJ', 'LP_J', '129S1_SvImJ', 'DBA_2J', 'AKR_J', 'CBA_J', 'NZO_HlLtJ', 'NOD_ShiLtJ', 'WSB_EiJ', 'CAST_EiJ', 'PWK_PhJ', 'SPRET_EiJ')

# Define the desired order of Measure_Names based on unique, unique loci, and multi loci
desired_measure_order <- c( "Unique", "Multiple Loci","Many Loci")  # Replace with your order

# Create a custom factor with the desired order for Measure_Names
data$Measure_Names <- factor(data$Measure_Names, levels = desired_measure_order)

# Create a custom factor with the desired order for Strains
data$Strains <- factor(data$Strains, levels = desired_strains_order)

# Define custom colors for stacked bars and error bars
stacked_bar_colors <- c("#ff7f0e","#1f77b4",  "#2ca02c", "#d62728")  # Replace with your colors
error_bar_color <- "#000000"   # Replace with your color

# Create the stacked bar plot with error bars using ggbarplot
ggbarplot(data = data,
          x = "Timepoint", y = "Measure_Values", 
          fill = "Measure_Names",
          add = "mean_se",
          nrow =1,
          facet.by = "Strains",
          error.plot = "errorbar")  +
  labs(title = "Bulk RNA STAR Mapping",
       x = "Timepoint", y = "%") +
  theme_minimal() +
  theme(legend.position = "bottom",
        axis.text.x = element_text(angle = 90, hjust = 1),
        strip.text.x = element_text(angle = 90, vjust = 0.5, hjust = 1),
        panel.spacing = unit(0.05, "lines"))
# Out:
# Warning message in stats::qt(ci/2 + 0.5, data_sum$length - 1):
# “NaNs produced”
# Warning message in stats::qt(ci/2 + 0.5, data_sum$length - 1):
# “NaNs produced”
# Warning message in stats::qt(ci/2 + 0.5, data_sum$length - 1):
# “NaNs produced”
# Warning message in stats::qt(ci/2 + 0.5, data_sum$length - 1):
# “NaNs produced”
# Warning message in stats::qt(ci/2 + 0.5, data_sum$length - 1):
# “NaNs produced”
# Warning message in stats::qt(ci/2 + 0.5, data_sum$length - 1):
# “NaNs produced”
# Warning message in stats::qt(ci/2 + 0.5, data_sum$length - 1):
# “NaNs produced”
# Warning message in stats::qt(ci/2 + 0.5, data_sum$length - 1):
# “NaNs produced”
# Warning message in stats::qt(ci/2 + 0.5, data_sum$length - 1):
# “NaNs produced”
# Warning message in stats::qt(ci/2 + 0.5, data_sum$length - 1):
# “NaNs produced”
# Warning message in stats::qt(ci/2 + 0.5, data_sum$length - 1):
# “NaNs produced”
# Warning message in stats::qt(ci/2 + 0.5, data_sum$length - 1):
# “NaNs produced”
# ...

# %%
# Read the data from the CSV file
data <- read.table("/mnt/home3/miska/nm667/scratch/inProgress/mice_PiRNA/analysis/RNA_deSeq/RNA_Mapping.csv", header = TRUE, sep = "\t")
data
# Define the desired order of Strains
desired_strains_order <- c('C57BL_6NJ', 'BALB_cJ', 'A_J', 'FVB_NJ', 'C3H_HeJ', 'LP_J', '129S1_SvImJ', 'DBA_2J', 'AKR_J', 'CBA_J', 'NZO_HlLtJ', 'NOD_ShiLtJ', 'WSB_EiJ', 'CAST_EiJ', 'PWK_PhJ', 'SPRET_EiJ')

# Define the desired order of Measure_Names based on unique, unique loci, and multi loci
desired_measure_order <- c( "Unique", "Multiple Loci","Many Loci")  # Replace with your order

# Create a custom factor with the desired order for Measure_Names
data$Measure_Names <- factor(data$Measure_Names, levels = desired_measure_order)

# Create a custom factor with the desired order for Strains
data$Strains <- factor(data$Strains, levels = desired_strains_order)

# Define custom colors for stacked bars and error bars
stacked_bar_colors <- c("#ff7f0e","#1f77b4",  "#2ca02c", "#d62728")  # Replace with your colors
error_bar_color <- "#000000"   # Replace with your color

# Calculate the average values for each strain
average_data <- aggregate(Measure_Values ~ Strains + Timepoint + Measure_Names, data, mean)

# Create the stacked bar plot with error bars using ggbarplot
library(ggpubr)

plot <- ggbarplot(data,
          x = "Timepoint", y = "Measure_Values", 
          fill = "Measure_Names",
          add = "mean_se",
          facet.by= "Strains",
          error.plot = "errorbar") 

plot
# Out:
#     Strains     Timepoint Replicates Measure_Names Measure_Values
# 1   129S1_SvImJ E16.5     3          Many Loci      0.06
# 2   129S1_SvImJ E16.5     2          Many Loci      0.05
# 3   129S1_SvImJ E16.5     1          Many Loci      0.05
# 4   129S1_SvImJ E16.5     3          Unique        88.73
# 5   129S1_SvImJ E16.5     2          Unique        88.99
# 6   129S1_SvImJ E16.5     1          Unique        87.01
# 7   129S1_SvImJ E16.5     3          Multiple Loci  5.94
# 8   129S1_SvImJ E16.5     2          Multiple Loci  6.30
# 9   129S1_SvImJ E16.5     1          Multiple Loci  7.33
# 10  129S1_SvImJ P12.5     3          Many Loci      0.05
# 11  129S1_SvImJ P12.5     2          Many Loci      0.05
# 12  129S1_SvImJ P12.5     1          Many Loci      0.05
# 13  129S1_SvImJ P12.5     3          Unique        89.73
# 14  129S1_SvImJ P12.5     2          Unique        91.28
# 15  129S1_SvImJ P12.5     1          Unique        90.83
# ...

# %%
# Load the required libraries
library(ggpubr)
library(ggplot2)


# Read the data from the CSV file
data <- read.table("/mnt/home3/miska/nm667/scratch/inProgress/mice_PiRNA/analysis/RNA_deSeq/RNA_Mapping.csv", header = TRUE, sep = "\t")

# Define the desired order of Strains
desired_strains_order <- c('C57BL_6NJ', 'BALB_cJ', 'A_J', 'FVB_NJ', 'C3H_HeJ', 'LP_J', '129S1_SvImJ', 'DBA_2J', 'AKR_J', 'CBA_J', 'NZO_HlLtJ', 'NOD_ShiLtJ', 'WSB_EiJ', 'CAST_EiJ', 'PWK_PhJ', 'SPRET_EiJ')

# Define the desired order of Measure_Names based on unique, unique loci, and multi loci
desired_measure_order <- c( "Unique", "Multiple Loci","Many Loci")  # Replace with your order

# Create a custom factor with the desired order for Measure_Names
data$Measure_Names <- factor(data$Measure_Names, levels = desired_measure_order)

# Create a custom factor with the desired order for Strains
data$Strains <- factor(data$Strains, levels = desired_strains_order)

# Define custom colors for stacked bars and error bars
stacked_bar_colors <- c("#ff7f0e","#1f77b4",  "#2ca02c", "#d62728")  # Replace with your colors
error_bar_color <- "#000000"   # Replace with your color

# Your existing code for reading and preprocessing data here...

# Create the stacked bar plot with error bars using ggbarplot
plot <- ggbarplot(data,
          x = "Timepoint", y = "Measure_Values", 
          fill= "Measure_Names",
          add = "mean_se",
          width =0.9,
          size= 0.4,
          nrow= 1,
          facet.by = "Strains",
          error.plot = "errorbar",
          title = "Bulk RNA Mapping Rate") + 
  theme_pubr() +  # Apply ggpubr theme for consistency
  labs(x = "Timepoint", y = "%",fill = "Mapping Rate") +  # Customize axis labels
  scale_fill_manual(values = stacked_bar_colors) +  # Set custom fill colors  
  theme_minimal() +
   theme(axis.text.x = element_text(angle = 90, hjust = 1),
   strip.text.x = element_text(angle = 90, vjust = 0.5, hjust = 0.1))# Rotate x-axis labels for better readability
 

# Save the plot as a PDF file
ggsave("RNA_MApping_stacked_bar_plot.pdf", plot = plot, device = "pdf", width = 8, height = 4)
# Out:
# plot without title

# %%
# Load required libraries
library(ggpubr)
library(ggplot2)

# Read the data from the CSV file
data <- read.table("/mnt/home3/miska/nm667/scratch/inProgress/mice_PiRNA/analysis/RNA_deSeq/RNA_Mapping.csv", header = TRUE, sep = "\t")


# Define the desired order of Strains
desired_strains_order <- c('C57BL_6NJ', 'BALB_cJ', 'A_J', 'FVB_NJ', 'C3H_HeJ', 'LP_J', '129S1_SvImJ', 'DBA_2J', 'AKR_J', 'CBA_J', 'NZO_HlLtJ', 'NOD_ShiLtJ', 'WSB_EiJ', 'CAST_EiJ', 'PWK_PhJ', 'SPRET_EiJ')

# Define the desired order of Measure_Names based on unique, unique loci, and multi loci
desired_measure_order <- c( "Unique", "Multiple Loci","Many Loci")  # Replace with your order

# Create a custom factor with the desired order for Measure_Names
data$Measure_Names <- factor(data$Measure_Names, levels = desired_measure_order)

# Create a custom factor with the desired order for Strains
data$Strains <- factor(data$Strains, levels = desired_strains_order)

# Define custom colors for stacked bars and error bars
stacked_bar_colors <- c("#ff7f0e","#1f77b4",  "#2ca02c", "#d62728")  # Replace with your colors
error_bar_color <- "#000000"   # Replace with your color




# Create the stacked bar plot with error bars
ggbarplot(data = data,
          x = "Timepoint", y = "Measure_Values", 
          fill = "Measure_Names",
          add = "mean_se",
          facet.by= "Strains",
          error.plot = "errorbar") +
  labs(title = "Bulk RNA STAR Mapping",
       , y = "%") +  # Remove x-axis label
  theme_minimal() +
  theme(legend.position = "bottom",
        axis.text.x = element_text(angle = 90, hjust = 1),
        axis.title.x = element_blank()) +  # Remove x-axis title
  scale_x_discrete(labels = data$Strains, name = "Strains")  # Use strain names as x-axis labels
# Out:
# plot without title

# %%
# Read the data from the CSV file
data <- read.table("/mnt/home3/miska/nm667/scratch/inProgress/mice_PiRNA/analysis/RNA_deSeq/RNA_Mapping.csv", header = TRUE, sep = "\t")

# Define the desired order of Strains
desired_strains_order <- c('C57BL_6NJ', 'BALB_cJ', 'A_J', 'FVB_NJ', 'C3H_HeJ', 'LP_J', '129S1_SvImJ', 'DBA_2J', 'AKR_J', 'CBA_J', 'NZO_HlLtJ', 'NOD_ShiLtJ', 'WSB_EiJ', 'CAST_EiJ', 'PWK_PhJ', 'SPRET_EiJ')

# Define the desired order of Measure_Names based on unique, unique loci, and multi loci
desired_measure_order <- c("Unique", "Multiple Loci", "Many Loci")  # Replace with your order

# Create a custom factor with the desired order for Measure_Names
data$Measure_Names <- factor(data$Measure_Names, levels = desired_measure_order)

# Create a custom factor with the desired order for Strains
data$Strains <- factor(data$Strains, levels = desired_strains_order)

# Define custom colors for stacked bars and error bars
stacked_bar_colors <- c("#ff7f0e", "#1f77b4", "#2ca02c", "#d62728")  # Replace with your colors
error_bar_color <- "#000000"  # Replace with your color


# Create a function to generate plots for individual strains
generate_strain_plot <- function(strain_data, first_grid = TRUE) {
  ggbarplot(data = strain_data,
            x = "Timepoint", y = "Measure_Values",
            fill = "Measure_Names",
            add = "mean_se",
            error.plot = "errorbar") +
             theme_minimal() + 
            theme_void() + 
    facet_wrap(~ Strains, , scales = ifelse(first_grid, "fixed", "free_y"),as.table = TRUE,strip.position = "top") +
    theme(legend.position = "none", axis.text.x = element_text(angle = 90, hjust = 0.1),
    strip.text.x = element_text(angle = 90, vjust = 0.5, hjust = 0.1)) +
    coord_cartesian(ylim = c(0, 100)) + 
    theme(strip.background = element_blank(), strip.placement = "outside")# Facet by Strains with free y-axes

}
# Generate plots for each strain
library(ggpubr)
strain_plots <- lapply(split(data, data$Strains), generate_strain_plot)

# Arrange the plots in a grid
library(gridExtra)
grid.arrange(grobs = strain_plots, ncol = 16)  # Ad
# Out:
# plot without title

# %%
# Load necessary libraries
library(ggplot2)
library(ggpubr)
library(gridExtra)

# Read the data from the CSV file
data <- read.table("/mnt/home3/miska/nm667/scratch/inProgress/mice_PiRNA/analysis/RNA_deSeq/RNA_Mapping.csv", header = TRUE, sep = "\t")

# Define the desired order of Strains
desired_strains_order <- c('C57BL_6NJ', 'BALB_cJ', 'A_J', 'FVB_NJ', 'C3H_HeJ', 'LP_J', '129S1_SvImJ', 'DBA_2J', 'AKR_J', 'CBA_J', 'NZO_HlLtJ', 'NOD_ShiLtJ', 'WSB_EiJ', 'CAST_EiJ', 'PWK_PhJ', 'SPRET_EiJ')

# Define the desired order of Measure_Names based on unique, unique loci, and multi loci
desired_measure_order <- c("Unique", "Multiple Loci", "Many Loci")  # Replace with your order

# Create a custom factor with the desired order for Measure_Names
data$Measure_Names <- factor(data$Measure_Names, levels = desired_measure_order)

# Create a custom factor with the desired order for Strains
data$Strains <- factor(data$Strains, levels = desired_strains_order)

# Define custom colors for stacked bars and error bars
stacked_bar_colors <- c("#ff7f0e", "#1f77b4", "#2ca02c", "#d62728")  # Replace with your colors
error_bar_color <- "#000000"  # Replace with your color

# Create a function to generate plots for individual strains
generate_strain_plot <- function(strain_data) {
  ggbarplot(data = strain_data,
            x = "Timepoint", y = "Measure_Values",
            fill = "Measure_Names",
            add = "mean_se",
            error.plot = "errorbar") +
            scale_fill_manual(values = stacked_bar_colors) +
    theme_minimal() + 
    theme_void() +  # Add the minimal theme elements back
    theme(panel.grid.major = element_line(color = "gray", size = 0.2),  # Customize grid lines
          panel.grid.minor = element_blank(),  # Remove minor grid lines
          plot.background = element_rect(fill = "white")) +  
    facet_wrap(~ Strains,  scales = "fixed") +
    theme(legend.position = "none", axis.text.x = element_text(angle = 90),
          strip.text.x = element_text(angle = 90, vjust = 0.5, hjust = 0.1, size = 8, margin = margin(10)),  # Set margin for all directions
          strip.background = element_blank()) +  # Remove strip background
    coord_cartesian(ylim = c(0, 100)) +  # Adjust y-axis limits if needed
    guides(fill = guide_legend(title = "Measure Values"))  # Add a common legend title
}

# Generate plots for each strain
strain_plots <- lapply(split(data, data$Strains), generate_strain_plot)

# Arrange the plots in a grid
grid.arrange(grobs = strain_plots, ncol = 16)
# Out:
# plot without title

# %%
# Load necessary libraries
library(ggplot2)
library(ggpubr)
library(gridExtra)

# Read the data from the CSV file
data <- read.table("/mnt/home3/miska/nm667/scratch/inProgress/mice_PiRNA/analysis/RNA_deSeq/RNA_Mapping.csv", header = TRUE, sep = "\t")

# Define the desired order of Strains
desired_strains_order <- c('C57BL_6NJ', 'BALB_cJ', 'A_J', 'FVB_NJ', 'C3H_HeJ', 'LP_J', '129S1_SvImJ', 'DBA_2J', 'AKR_J', 'CBA_J', 'NZO_HlLtJ', 'NOD_ShiLtJ', 'WSB_EiJ', 'CAST_EiJ', 'PWK_PhJ', 'SPRET_EiJ')

# Define the desired order of Measure_Names based on unique, unique loci, and multi loci
desired_measure_order <- c("Unique", "Multiple Loci", "Many Loci")  # Replace with your order

# Create a custom factor with the desired order for Measure_Names
data$Measure_Names <- factor(data$Measure_Names, levels = desired_measure_order)

# Create a custom factor with the desired order for Strains
data$Strains <- factor(data$Strains, levels = desired_strains_order)

# Define custom colors for stacked bars and error bars
stacked_bar_colors <- c("#ff7f0e", "#1f77b4", "#2ca02c", "#d62728")  # Replace with your colors
error_bar_color <- "#000000"  # Replace with your color

# Create a function to generate plots for individual strains
generate_strain_plot <- function(strain_data) {
  ggbarplot(data = strain_data,
            x = "Timepoint", y = "Measure_Values",
            color = "Measure_Names",
            add = "mean_se",
            facet.by= "Strains",
            error.plot = "errorbar") +
            scale_fill_manual(values = stacked_bar_colors) +
    theme_minimal() + 
    theme_void() +  # Add the minimal theme elements back
    theme(panel.grid.major = element_line(color = "gray", size = 0.2),  # Customize grid lines
          panel.grid.minor = element_blank(),  # Remove minor grid lines
          plot.background = element_rect(fill = "white")) +  
    theme(legend.position = "none", axis.text.x = element_text(angle = 90),
          strip.text.x = element_text(angle = 90, vjust = 0.5, hjust = 0.1, size = 8, margin = margin(10)),  # Set margin for all directions
          strip.background = element_blank()) +  # Remove strip background
    coord_cartesian(ylim = c(0, 100)) +  # Adjust y-axis limits if needed
    guides(fill = guide_legend(title = "Measure Values"))  # Add a common legend title
}

# Generate plots for each strain
strain_plots <- lapply(split(data, data$Strains), generate_strain_plot)

# Arrange the plots in a grid
grid.arrange(grobs = strain_plots, ncol = 16)
# Out:
# plot without title

# %%
# Load necessary libraries
library(ggplot2)
library(ggpubr)
library(gridExtra)

# Read the data from the CSV file
data <- read.table("/mnt/home3/miska/nm667/scratch/inProgress/mice_PiRNA/analysis/RNA_deSeq/RNA_Mapping.csv", header = TRUE, sep = "\t")

# Define the desired order of Strains
desired_strains_order <- c('C57BL_6NJ', 'BALB_cJ', 'A_J', 'FVB_NJ', 'C3H_HeJ', 'LP_J', '129S1_SvImJ', 'DBA_2J', 'AKR_J', 'CBA_J', 'NZO_HlLtJ', 'NOD_ShiLtJ', 'WSB_EiJ', 'CAST_EiJ', 'PWK_PhJ', 'SPRET_EiJ')

# Define the desired order of Measure_Names based on unique, unique loci, and multi loci
desired_measure_order <- c("Unique", "Multiple Loci", "Many Loci")  # Replace with your order

# Create a custom factor with the desired order for Measure_Names
data$Measure_Names <- factor(data$Measure_Names, levels = desired_measure_order)

# Create a custom factor with the desired order for Strains
data$Strains <- factor(data$Strains, levels = desired_strains_order)

# Define custom colors for stacked bars and error bars
stacked_bar_colors <- c("#ff7f0e", "#1f77b4", "#2ca02c", "#d62728")  # Replace with your colors
error_bar_color <- "#000000"  # Replace with your color

# Create a function to generate plots for individual strains
generate_strain_plot <- function(strain_data) {
  ggplot(data = strain_data, aes(x = Timepoint, y = Measure_Values, fill = Measure_Names)) +
    geom_bar(stat = "identity", position = "stack") +
    geom_text(aes(label = Measure_Values), vjust = -0.5, size = 3,angle = 90, position = position_stack()) +
    scale_fill_manual(values = stacked_bar_colors) +
    theme_minimal() + 
    theme_void() +
    theme(panel.grid.major = element_line(color = "gray", size = 0.2),
          panel.grid.minor = element_blank(),
          plot.background = element_rect(fill = "white")) +
    facet_wrap(~ Strains, scales = "fixed", strip.position = "top") +
    theme(legend.position = "none", axis.text.x = element_text(angle = 90),
          strip.text.x = element_text(angle = 90, vjust = 0.5, hjust = 0.1, size = 8, margin = margin(10)),
          strip.background = element_blank()) +
    coord_cartesian(ylim = c(0, 100)) +
    guides(fill = guide_legend(title = "Measure Values"))
}

# Generate plots for each strain
strain_plots <- lapply(split(data, data$Strains), generate_strain_plot)

# Arrange the plots in a grid
grid.arrange(grobs = strain_plots, ncol = 16)
# Out:
# plot without title

# %%
library(ggplot2)  # Load the ggplot2 library

# Read the data from the CSV file
data <- read.table("/mnt/home3/miska/nm667/scratch/inProgress/mice_PiRNA/analysis/RNA_deSeq/RNA_Mapping.csv", header = TRUE, sep = "\t")

# Define the desired order of Strains
desired_strains_order <- c('C57BL_6NJ', 'BALB_cJ', 'A_J', 'FVB_NJ', 'C3H_HeJ', 'LP_J', '129S1_SvImJ', 'DBA_2J', 'AKR_J', 'CBA_J', 'NZO_HlLtJ', 'NOD_ShiLtJ', 'WSB_EiJ', 'CAST_EiJ', 'PWK_PhJ', 'SPRET_EiJ')

# Define the desired order of Measure_Names based on unique, unique loci, and multi loci
desired_measure_order <- c("Unique", "Multiple Loci", "Many Loci")

# Create a custom factor with the desired order for Measure_Names
data$Measure_Names <- factor(data$Measure_Names, levels = desired_measure_order)

# Create a custom factor with the desired order for Strains
data$Strains <- factor(data$Strains, levels = desired_strains_order)

# Define custom colors for stacked bars and error bars
stacked_bar_colors <- c("#ff7f0e", "#1f77b4", "#2ca02c", "#d62728")  # Replace with your colors
error_bar_color <- "#000000"   # Replace with your color

# Create the stacked bar plot with error bars using ggplot
ggplot(data, aes(x = Timepoint, y = Measure_Values, fill = Measure_Names)) +
  geom_bar(stat = "identity", position = "stack") +
  geom_errorbar(aes(ymin = Measure_Values , ymax = Measure_Values ),
                position = position_dodge(0.9), width = 0.25,
                color = error_bar_color) +
  facet_grid(. ~ Strains) +
  labs(title = "Bulk RNA STAR Mapping",
       x = "Timepoint", y = "%") +
  theme_minimal() +
  theme(legend.position = "bottom",
        axis.text.x = element_text(angle = 90, hjust = 1),
        strip.text.x = element_text(angle = 90, vjust = 0.5, hjust = 1),
        panel.spacing = unit(0.05, "lines"))
# Out:
# plot without title
