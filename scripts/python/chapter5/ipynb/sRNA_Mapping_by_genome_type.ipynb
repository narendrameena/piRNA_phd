# %%
library(ggplot2)
library(dplyr)
# Load the required libraries
library(ggpubr)

# %%
setwd("/mnt/home3/miska/nm667/scratch/inProgress/mice_PiRNA/analysis/sRNA_deseq/sRNA_STAR_testing")

# %%
data <- read.csv("/mnt/home3/miska/nm667/scratch/inProgress/mice_PiRNA/analysis/sRNA_deseq/data/sRNA_all_genome_type_mapping.csv", header=TRUE,sep=';')
data
# Round the values in the Measure_Values column to two decimal places
data$Measure.Values <- round(data$Measure.Values, 2)
# Remove rows with NA values using na.omit
data <- na.omit(data)
# Define the desired order of Strains
desired_strains_order <- c('C57BL_6NJ', 'BALB_cJ', 'A_J', 'FVB_NJ', 'C3H_HeJ', 'LP_J', '129S1_SvImJ', 'DBA_2J', 'AKR_J', 'CBA_J', 'NZO_HlLtJ', 'NOD_ShiLtJ', 'WSB_EiJ', 'CAST_EiJ', 'PWK_PhJ', 'SPRET_EiJ')

# Define the desired order of Measure_Names based on unique, unique loci, and multi loci
desired_measure_order <- c( "Reads Mapped To Too Many Loci","Reads Mapped To Multiple Loci", "Uniquely mapped reads" )  # Replace with your order

# Define the desired order for Timepoint
desired_timepoint_order <- c("E16.5", "P12.5", "P20.5")


desired_genome_order <- c( "GRCm38","GRCm39", "illumina" ,"Pac-Bio")
# Out:
#      Timepoint Strains     genomes  Replicates Measure.Names
# 1    E16.5     129S1_SvImJ GRCm38   3          Uniquely mapped reads
# 2    E16.5     129S1_SvImJ GRCm38   2          Uniquely mapped reads
# 3    E16.5     129S1_SvImJ GRCm38   1          Uniquely mapped reads
# 4    E16.5     129S1_SvImJ GRCm38   3          Reads Mapped To Multiple Loci
# 5    E16.5     129S1_SvImJ GRCm38   2          Reads Mapped To Multiple Loci
# 6    E16.5     129S1_SvImJ GRCm38   1          Reads Mapped To Multiple Loci
# 7    E16.5     129S1_SvImJ GRCm38   3          Reads Mapped To Too Many Loci
# 8    E16.5     129S1_SvImJ GRCm38   2          Reads Mapped To Too Many Loci
# 9    E16.5     129S1_SvImJ GRCm38   1          Reads Mapped To Too Many Loci
# 10   E16.5     129S1_SvImJ GRCm39   3          Uniquely mapped reads
# 11   E16.5     129S1_SvImJ GRCm39   2          Uniquely mapped reads
# 12   E16.5     129S1_SvImJ GRCm39   1          Uniquely mapped reads
# 13   E16.5     129S1_SvImJ GRCm39   3          Reads Mapped To Multiple Loci
# 14   E16.5     129S1_SvImJ GRCm39   2          Reads Mapped To Multiple Loci
# 15   E16.5     129S1_SvImJ GRCm39   1          Reads Mapped To Multiple Loci
# 16   E16.5     129S1_SvImJ GRCm39   3          Reads Mapped To Too Many Loci
# 17   E16.5     129S1_SvImJ GRCm39   2          Reads Mapped To Too Many Loci
# 18   E16.5     129S1_SvImJ GRCm39   1          Reads Mapped To Too Many Loci
# 19   E16.5     129S1_SvImJ illumina 3          Uniquely mapped reads
# 20   E16.5     129S1_SvImJ illumina 2          Uniquely mapped reads
# 21   E16.5     129S1_SvImJ illumina 1          Uniquely mapped reads
# 22   E16.5     129S1_SvImJ illumina 3          Reads Mapped To Multiple Loci
# 23   E16.5     129S1_SvImJ illumina 2          Reads Mapped To Multiple Loci
# 24   E16.5     129S1_SvImJ illumina 1          Reads Mapped To Multiple Loci
# 25   E16.5     129S1_SvImJ illumina 3          Reads Mapped To Too Many Loci
# 26   E16.5     129S1_SvImJ illumina 2          Reads Mapped To Too Many Loci
# 27   E16.5     129S1_SvImJ illumina 1          Reads Mapped To Too Many Loci
# 28   E16.5     129S1_SvImJ Pac-Bio  3          Uniquely mapped reads
# 29   E16.5     129S1_SvImJ Pac-Bio  2          Uniquely mapped reads
# 30   E16.5     129S1_SvImJ Pac-Bio  1          Uniquely mapped reads
# ⋮    ⋮         ⋮           ⋮        ⋮          ⋮
# 1699 P20.5     WSB_EiJ     GRCm38   3          Reads Mapped To Too Many Loci
# 1700 P20.5     WSB_EiJ     GRCm38   2          Reads Mapped To Too Many Loci
# 1701 P20.5     WSB_EiJ     GRCm38   1          Reads Mapped To Too Many Loci
# 1702 P20.5     WSB_EiJ     GRCm39   3          Uniquely mapped reads
# 1703 P20.5     WSB_EiJ     GRCm39   2          Uniquely mapped reads
# 1704 P20.5     WSB_EiJ     GRCm39   1          Uniquely mapped reads
# 1705 P20.5     WSB_EiJ     GRCm39   3          Reads Mapped To Multiple Loci
# 1706 P20.5     WSB_EiJ     GRCm39   2          Reads Mapped To Multiple Loci
# 1707 P20.5     WSB_EiJ     GRCm39   1          Reads Mapped To Multiple Loci
# 1708 P20.5     WSB_EiJ     GRCm39   3          Reads Mapped To Too Many Loci
# 1709 P20.5     WSB_EiJ     GRCm39   2          Reads Mapped To Too Many Loci
# 1710 P20.5     WSB_EiJ     GRCm39   1          Reads Mapped To Too Many Loci
# 1711 P20.5     WSB_EiJ     illumina 3          Uniquely mapped reads
# 1712 P20.5     WSB_EiJ     illumina 2          Uniquely mapped reads
# 1713 P20.5     WSB_EiJ     illumina 1          Uniquely mapped reads
# 1714 P20.5     WSB_EiJ     illumina 3          Reads Mapped To Multiple Loci
# 1715 P20.5     WSB_EiJ     illumina 2          Reads Mapped To Multiple Loci
# 1716 P20.5     WSB_EiJ     illumina 1          Reads Mapped To Multiple Loci
# 1717 P20.5     WSB_EiJ     illumina 3          Reads Mapped To Too Many Loci
# 1718 P20.5     WSB_EiJ     illumina 2          Reads Mapped To Too Many Loci
# 1719 P20.5     WSB_EiJ     illumina 1          Reads Mapped To Too Many Loci
# 1720 P20.5     WSB_EiJ     Pac-Bio  3          Uniquely mapped reads
# 1721 P20.5     WSB_EiJ     Pac-Bio  2          Uniquely mapped reads
# 1722 P20.5     WSB_EiJ     Pac-Bio  1          Uniquely mapped reads
# 1723 P20.5     WSB_EiJ     Pac-Bio  3          Reads Mapped To Multiple Loci
# 1724 P20.5     WSB_EiJ     Pac-Bio  2          Reads Mapped To Multiple Loci
# 1725 P20.5     WSB_EiJ     Pac-Bio  1          Reads Mapped To Multiple Loci
# 1726 P20.5     WSB_EiJ     Pac-Bio  3          Reads Mapped To Too Many Loci
# 1727 P20.5     WSB_EiJ     Pac-Bio  2          Reads Mapped To Too Many Loci
# 1728 P20.5     WSB_EiJ     Pac-Bio  1          Reads Mapped To Too Many Loci
#      Measure.Values
# 1    42.15
# 2    42.25
# 3    43.67
# 4    29.81
# 5    31.47
# 6    29.39
# 7     3.53
# 8     3.37
# 9     3.61
# 10   28.84
# 11   28.93
# 12   30.22
# 13   14.39
# 14   13.89
# 15   15.35
# 16    0.00
# 17    0.00
# 18    0.00
# 19   46.16
# 20   47.23
# 21   47.74
# 22   32.31
# 23   32.98
# 24   32.71
# 25    2.00
# 26    1.93
# 27    2.12
# 28   45.16
# 29   45.32
# 30   46.75
# ⋮    ⋮
# 1699  0.43
# 1700  0.55
# 1701  0.23
# 1702 58.54
# 1703 58.15
# 1704 59.32
# 1705  4.89
# 1706  5.11
# 1707  4.40
# 1708  0.00
# 1709  0.00
# 1710  0.00
# 1711 73.43
# 1712 72.94
# 1713 74.60
# 1714  6.49
# 1715  6.94
# 1716  5.18
# 1717  0.29
# 1718  0.38
# 1719  0.19
# 1720 73.37
# 1721 72.87
# 1722 74.76
# 1723  8.34
# 1724  8.79
# 1725  6.91
# 1726  0.42
# 1727  0.54
# 1728  0.22

# %%
# Create a custom factor with the desired order for Timepoint
data$Timepoint <- factor(data$Timepoint, levels = desired_timepoint_order)

# Create a custom factor with the desired order for Measure_Names
data$Measure.Names <- factor(data$Measure.Names, levels = desired_measure_order)


data$genomes <- factor(data$genomes, levels = desired_genome_order)
# Create a custom factor with the desired order for Strains
data$Strains <- factor(data$Strains, levels = desired_strains_order)

# Define custom colors for stacked bars and error bars
stacked_bar_colors <- c( "#1f77b4","#2ca02c","#ff7f0e", "#d62728" )  # Replace with your colors
error_bar_color <- "#000000"   # Replace with your color

# %%
filter(data, Measure.Names == "Uniquely mapped reads")
# Out:
#     Timepoint Strains     genomes  Replicates Measure.Names
# 1   E16.5     129S1_SvImJ GRCm38   3          Uniquely mapped reads
# 2   E16.5     129S1_SvImJ GRCm38   2          Uniquely mapped reads
# 3   E16.5     129S1_SvImJ GRCm38   1          Uniquely mapped reads
# 4   E16.5     129S1_SvImJ GRCm39   3          Uniquely mapped reads
# 5   E16.5     129S1_SvImJ GRCm39   2          Uniquely mapped reads
# 6   E16.5     129S1_SvImJ GRCm39   1          Uniquely mapped reads
# 7   E16.5     129S1_SvImJ illumina 3          Uniquely mapped reads
# 8   E16.5     129S1_SvImJ illumina 2          Uniquely mapped reads
# 9   E16.5     129S1_SvImJ illumina 1          Uniquely mapped reads
# 10  E16.5     129S1_SvImJ Pac-Bio  3          Uniquely mapped reads
# 11  E16.5     129S1_SvImJ Pac-Bio  2          Uniquely mapped reads
# 12  E16.5     129S1_SvImJ Pac-Bio  1          Uniquely mapped reads
# 13  E16.5     A_J         GRCm38   3          Uniquely mapped reads
# 14  E16.5     A_J         GRCm38   2          Uniquely mapped reads
# 15  E16.5     A_J         GRCm38   1          Uniquely mapped reads
# 16  E16.5     A_J         GRCm39   3          Uniquely mapped reads
# 17  E16.5     A_J         GRCm39   2          Uniquely mapped reads
# 18  E16.5     A_J         GRCm39   1          Uniquely mapped reads
# 19  E16.5     A_J         illumina 3          Uniquely mapped reads
# 20  E16.5     A_J         illumina 2          Uniquely mapped reads
# 21  E16.5     A_J         illumina 1          Uniquely mapped reads
# 22  E16.5     A_J         Pac-Bio  3          Uniquely mapped reads
# 23  E16.5     A_J         Pac-Bio  2          Uniquely mapped reads
# 24  E16.5     A_J         Pac-Bio  1          Uniquely mapped reads
# 25  E16.5     AKR_J       GRCm38   3          Uniquely mapped reads
# 26  E16.5     AKR_J       GRCm38   2          Uniquely mapped reads
# 27  E16.5     AKR_J       GRCm38   1          Uniquely mapped reads
# 28  E16.5     AKR_J       GRCm39   3          Uniquely mapped reads
# 29  E16.5     AKR_J       GRCm39   2          Uniquely mapped reads
# 30  E16.5     AKR_J       GRCm39   1          Uniquely mapped reads
# ⋮   ⋮         ⋮           ⋮        ⋮          ⋮
# 547 P20.5     PWK_PhJ     illumina 3          Uniquely mapped reads
# 548 P20.5     PWK_PhJ     illumina 2          Uniquely mapped reads
# 549 P20.5     PWK_PhJ     illumina 1          Uniquely mapped reads
# 550 P20.5     PWK_PhJ     Pac-Bio  3          Uniquely mapped reads
# 551 P20.5     PWK_PhJ     Pac-Bio  2          Uniquely mapped reads
# 552 P20.5     PWK_PhJ     Pac-Bio  1          Uniquely mapped reads
# 553 P20.5     SPRET_EiJ   GRCm38   3          Uniquely mapped reads
# 554 P20.5     SPRET_EiJ   GRCm38   2          Uniquely mapped reads
# 555 P20.5     SPRET_EiJ   GRCm38   1          Uniquely mapped reads
# 556 P20.5     SPRET_EiJ   GRCm39   3          Uniquely mapped reads
# 557 P20.5     SPRET_EiJ   GRCm39   2          Uniquely mapped reads
# 558 P20.5     SPRET_EiJ   GRCm39   1          Uniquely mapped reads
# 559 P20.5     SPRET_EiJ   illumina 3          Uniquely mapped reads
# 560 P20.5     SPRET_EiJ   illumina 2          Uniquely mapped reads
# 561 P20.5     SPRET_EiJ   illumina 1          Uniquely mapped reads
# 562 P20.5     SPRET_EiJ   Pac-Bio  3          Uniquely mapped reads
# 563 P20.5     SPRET_EiJ   Pac-Bio  2          Uniquely mapped reads
# 564 P20.5     SPRET_EiJ   Pac-Bio  1          Uniquely mapped reads
# 565 P20.5     WSB_EiJ     GRCm38   3          Uniquely mapped reads
# 566 P20.5     WSB_EiJ     GRCm38   2          Uniquely mapped reads
# 567 P20.5     WSB_EiJ     GRCm38   1          Uniquely mapped reads
# 568 P20.5     WSB_EiJ     GRCm39   3          Uniquely mapped reads
# 569 P20.5     WSB_EiJ     GRCm39   2          Uniquely mapped reads
# 570 P20.5     WSB_EiJ     GRCm39   1          Uniquely mapped reads
# 571 P20.5     WSB_EiJ     illumina 3          Uniquely mapped reads
# 572 P20.5     WSB_EiJ     illumina 2          Uniquely mapped reads
# 573 P20.5     WSB_EiJ     illumina 1          Uniquely mapped reads
# 574 P20.5     WSB_EiJ     Pac-Bio  3          Uniquely mapped reads
# 575 P20.5     WSB_EiJ     Pac-Bio  2          Uniquely mapped reads
# 576 P20.5     WSB_EiJ     Pac-Bio  1          Uniquely mapped reads
#     Measure.Values
# 1   42.15
# 2   42.25
# 3   43.67
# 4   28.84
# 5   28.93
# 6   30.22
# 7   46.16
# 8   47.23
# 9   47.74
# 10  45.16
# 11  45.32
# 12  46.75
# 13  48.91
# 14  51.74
# 15  47.09
# 16  37.03
# 17  39.07
# 18  36.33
# 19  54.32
# 20  56.93
# 21  53.92
# 22  51.88
# 23  54.90
# 24  49.87
# 25  42.45
# 26  38.70
# 27  42.89
# 28  30.97
# 29  28.70
# 30  30.33
# ⋮   ⋮
# 547 74.72
# 548 74.18
# 549 73.53
# 550 74.84
# 551 74.31
# 552 73.65
# 553 45.96
# 554 45.30
# 555 43.00
# 556 39.03
# 557 38.50
# 558 36.85
# 559 72.52
# 560 71.58
# 561 67.91
# 562 71.31
# 563 70.41
# 564 66.93
# 565 69.96
# 566 69.42
# 567 71.26
# 568 58.54
# 569 58.15
# 570 59.32
# 571 73.43
# 572 72.94
# 573 74.60
# 574 73.37
# 575 72.87
# 576 74.76

# %%
filter(data, Timepoint == "E16.5")
# Out:
#     Timepoint Strains     genomes  Replicates Measure.Names
# 1   E16.5     129S1_SvImJ GRCm38   3          Uniquely mapped reads
# 2   E16.5     129S1_SvImJ GRCm38   2          Uniquely mapped reads
# 3   E16.5     129S1_SvImJ GRCm38   1          Uniquely mapped reads
# 4   E16.5     129S1_SvImJ GRCm38   3          Reads Mapped To Multiple Loci
# 5   E16.5     129S1_SvImJ GRCm38   2          Reads Mapped To Multiple Loci
# 6   E16.5     129S1_SvImJ GRCm38   1          Reads Mapped To Multiple Loci
# 7   E16.5     129S1_SvImJ GRCm38   3          Reads Mapped To Too Many Loci
# 8   E16.5     129S1_SvImJ GRCm38   2          Reads Mapped To Too Many Loci
# 9   E16.5     129S1_SvImJ GRCm38   1          Reads Mapped To Too Many Loci
# 10  E16.5     129S1_SvImJ GRCm39   3          Uniquely mapped reads
# 11  E16.5     129S1_SvImJ GRCm39   2          Uniquely mapped reads
# 12  E16.5     129S1_SvImJ GRCm39   1          Uniquely mapped reads
# 13  E16.5     129S1_SvImJ GRCm39   3          Reads Mapped To Multiple Loci
# 14  E16.5     129S1_SvImJ GRCm39   2          Reads Mapped To Multiple Loci
# 15  E16.5     129S1_SvImJ GRCm39   1          Reads Mapped To Multiple Loci
# 16  E16.5     129S1_SvImJ GRCm39   3          Reads Mapped To Too Many Loci
# 17  E16.5     129S1_SvImJ GRCm39   2          Reads Mapped To Too Many Loci
# 18  E16.5     129S1_SvImJ GRCm39   1          Reads Mapped To Too Many Loci
# 19  E16.5     129S1_SvImJ illumina 3          Uniquely mapped reads
# 20  E16.5     129S1_SvImJ illumina 2          Uniquely mapped reads
# 21  E16.5     129S1_SvImJ illumina 1          Uniquely mapped reads
# 22  E16.5     129S1_SvImJ illumina 3          Reads Mapped To Multiple Loci
# 23  E16.5     129S1_SvImJ illumina 2          Reads Mapped To Multiple Loci
# 24  E16.5     129S1_SvImJ illumina 1          Reads Mapped To Multiple Loci
# 25  E16.5     129S1_SvImJ illumina 3          Reads Mapped To Too Many Loci
# 26  E16.5     129S1_SvImJ illumina 2          Reads Mapped To Too Many Loci
# 27  E16.5     129S1_SvImJ illumina 1          Reads Mapped To Too Many Loci
# 28  E16.5     129S1_SvImJ Pac-Bio  3          Uniquely mapped reads
# 29  E16.5     129S1_SvImJ Pac-Bio  2          Uniquely mapped reads
# 30  E16.5     129S1_SvImJ Pac-Bio  1          Uniquely mapped reads
# ⋮   ⋮         ⋮           ⋮        ⋮          ⋮
# 547 E16.5     WSB_EiJ     GRCm38   3          Reads Mapped To Too Many Loci
# 548 E16.5     WSB_EiJ     GRCm38   2          Reads Mapped To Too Many Loci
# 549 E16.5     WSB_EiJ     GRCm38   1          Reads Mapped To Too Many Loci
# 550 E16.5     WSB_EiJ     GRCm39   3          Uniquely mapped reads
# 551 E16.5     WSB_EiJ     GRCm39   2          Uniquely mapped reads
# 552 E16.5     WSB_EiJ     GRCm39   1          Uniquely mapped reads
# 553 E16.5     WSB_EiJ     GRCm39   3          Reads Mapped To Multiple Loci
# 554 E16.5     WSB_EiJ     GRCm39   2          Reads Mapped To Multiple Loci
# 555 E16.5     WSB_EiJ     GRCm39   1          Reads Mapped To Multiple Loci
# 556 E16.5     WSB_EiJ     GRCm39   3          Reads Mapped To Too Many Loci
# 557 E16.5     WSB_EiJ     GRCm39   2          Reads Mapped To Too Many Loci
# 558 E16.5     WSB_EiJ     GRCm39   1          Reads Mapped To Too Many Loci
# 559 E16.5     WSB_EiJ     illumina 3          Uniquely mapped reads
# 560 E16.5     WSB_EiJ     illumina 2          Uniquely mapped reads
# 561 E16.5     WSB_EiJ     illumina 1          Uniquely mapped reads
# 562 E16.5     WSB_EiJ     illumina 3          Reads Mapped To Multiple Loci
# 563 E16.5     WSB_EiJ     illumina 2          Reads Mapped To Multiple Loci
# 564 E16.5     WSB_EiJ     illumina 1          Reads Mapped To Multiple Loci
# 565 E16.5     WSB_EiJ     illumina 3          Reads Mapped To Too Many Loci
# 566 E16.5     WSB_EiJ     illumina 2          Reads Mapped To Too Many Loci
# 567 E16.5     WSB_EiJ     illumina 1          Reads Mapped To Too Many Loci
# 568 E16.5     WSB_EiJ     Pac-Bio  3          Uniquely mapped reads
# 569 E16.5     WSB_EiJ     Pac-Bio  2          Uniquely mapped reads
# 570 E16.5     WSB_EiJ     Pac-Bio  1          Uniquely mapped reads
# 571 E16.5     WSB_EiJ     Pac-Bio  3          Reads Mapped To Multiple Loci
# 572 E16.5     WSB_EiJ     Pac-Bio  2          Reads Mapped To Multiple Loci
# 573 E16.5     WSB_EiJ     Pac-Bio  1          Reads Mapped To Multiple Loci
# 574 E16.5     WSB_EiJ     Pac-Bio  3          Reads Mapped To Too Many Loci
# 575 E16.5     WSB_EiJ     Pac-Bio  2          Reads Mapped To Too Many Loci
# 576 E16.5     WSB_EiJ     Pac-Bio  1          Reads Mapped To Too Many Loci
#     Measure.Values
# 1   42.15
# 2   42.25
# 3   43.67
# 4   29.81
# 5   31.47
# 6   29.39
# 7    3.53
# 8    3.37
# 9    3.61
# 10  28.84
# 11  28.93
# 12  30.22
# 13  14.39
# 14  13.89
# 15  15.35
# 16   0.00
# 17   0.00
# 18   0.00
# 19  46.16
# 20  47.23
# 21  47.74
# 22  32.31
# 23  32.98
# 24  32.71
# 25   2.00
# 26   1.93
# 27   2.12
# 28  45.16
# 29  45.32
# 30  46.75
# ⋮   ⋮
# 547  3.48
# 548  3.49
# 549  3.90
# 550 21.51
# 551 21.79
# 552 25.68
# 553  5.79
# 554  5.84
# 555  7.12
# 556  0.00
# 557  0.00
# 558  0.00
# 559 28.01
# 560 28.48
# 561 36.13
# 562 38.66
# 563 40.68
# 564 30.58
# 565  0.29
# 566  0.29
# 567  0.46
# 568 27.26
# 569 27.64
# 570 35.34
# 571 44.67
# 572 46.86
# 573 38.38
# 574  3.19
# 575  3.21
# 576  3.61

# %%
# Your existing code for reading and preprocessing data here...
# Create the stacked bar plot with error bars using ggbarplot
plot <- ggbarplot(filter(data, Timepoint == 'E16.5'),
          x = "genomes", y = "Measure.Values", 
          fill= "Measure.Names",
          add = "mean_se",
          width =0.8,
          add.params = list(color = "#000000"),
          nrow =1,
          size= 0.4,
          facet.by = "Strains",
          error.plot = "errorbar",
          title = "E16.5 sRNA Mapping Rate") + 
   # Apply ggpubr theme for consistency  # Major breaks every 10
  geom_hline(yintercept = seq(0, 75, by = 5), linetype = "dashed", color = "lightgrey", size = 0.0001) + # Add minor grid lines
  geom_hline(yintercept = seq(0, 80, by = 10), linetype = "dashed", color = "lightgrey", size = 0.0001) + 
  labs(x = "Timepoint", y = "%") +  # Customize axis labels
  scale_fill_manual(values = stacked_bar_colors) +  # Set custom fill colors  
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 90, hjust = 1, size=6),
        strip.text.x = element_text(angle = 90, vjust = 0.5, hjust = 0.1),
        axis.ticks.y = element_line(color = "black"),
        panel.ontop = FALSE) +  # Ensure bars are drawn on top of grid lines
  scale_y_continuous(breaks = seq(0, 100, by = 10)) 


plot
# Save the plot as a PDF file
ggsave("sRNA_MApping_E16.5_by_genome_stacked_bar_plot.pdf", plot = plot, device = "pdf", width = 10, height = 4)
# Out:
# plot without title

# %%
# Your existing code for reading and preprocessing data here...
# Create the stacked bar plot with error bars using ggbarplot
plot <- ggbarplot(filter(data, Timepoint == 'P12.5'),
          x = "genomes", y = "Measure.Values", 
          fill= "Measure.Names",
          add = "mean_se",
          width =0.8,
          add.params = list(color = "#000000"),
          nrow =1,
          size= 0.4,
          facet.by = "Strains",
          error.plot = "errorbar",
          title = "P12.5 sRNA Mapping Rate") + 
   # Apply ggpubr theme for consistency  # Major breaks every 10
  geom_hline(yintercept = seq(0, 75, by = 5), linetype = "dashed", color = "lightgrey", size = 0.0001) + # Add minor grid lines
  geom_hline(yintercept = seq(0, 80, by = 10), linetype = "dashed", color = "lightgrey", size = 0.0001) + 
  labs(x = "Timepoint", y = "%") +  # Customize axis labels
  scale_fill_manual(values = stacked_bar_colors) +  # Set custom fill colors  
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 90, hjust = 1, size=6),
        strip.text.x = element_text(angle = 90, vjust = 0.5, hjust = 0.1),
        axis.ticks.y = element_line(color = "black"),
        panel.ontop = FALSE) +  # Ensure bars are drawn on top of grid lines
  scale_y_continuous(breaks = seq(0, 100, by = 10)) 


plot
# Save the plot as a PDF file
ggsave("sRNA_MApping_P12.5_by_genome_stacked_bar_plot.pdf", plot = plot, device = "pdf", width = 10, height = 4)
# Out:
# plot without title

# %%
# Your existing code for reading and preprocessing data here...
# Create the stacked bar plot with error bars using ggbarplot
plot <- ggbarplot(filter(data, Timepoint == 'P20.5'),
          x = "genomes", y = "Measure.Values", 
          fill= "Measure.Names",
          add = "mean_se",
          width =0.8,
          add.params = list(color = "#000000"),
          nrow =1,
          size= 0.4,
          facet.by = "Strains",
          error.plot = "errorbar",
          title = "P20.5 sRNA Mapping Rate") + 
   # Apply ggpubr theme for consistency  # Major breaks every 10
  geom_hline(yintercept = seq(0, 75, by = 5), linetype = "dashed", color = "lightgrey", size = 0.0001) + # Add minor grid lines
  geom_hline(yintercept = seq(0, 80, by = 10), linetype = "dashed", color = "lightgrey", size = 0.0001) + 
  labs(x = "Timepoint", y = "%") +  # Customize axis labels
  scale_fill_manual(values = stacked_bar_colors) +  # Set custom fill colors  
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 90, hjust = 1, size=6),
        strip.text.x = element_text(angle = 90, vjust = 0.5, hjust = 0.1),
        axis.ticks.y = element_line(color = "black"),
        panel.ontop = FALSE) +  # Ensure bars are drawn on top of grid lines
  scale_y_continuous(breaks = seq(0, 100, by = 10)) 


plot
# Save the plot as a PDF file
ggsave("sRNA_MApping_P20.5_by_genome_stacked_bar_plot.pdf", plot = plot, device = "pdf", width = 10, height = 4)
# Out:
# plot without title
